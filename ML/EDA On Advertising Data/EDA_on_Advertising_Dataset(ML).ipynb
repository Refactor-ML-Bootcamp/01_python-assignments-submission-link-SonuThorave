# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Advertising (1).csv')
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.shape
# Out:
# (200, 5)

# %%
df['Newspaper'].isnull().sum()
# Out:
# 0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
for col in df.columns[:-1]:
    plt.scatter(data=df,x=col,y='Sales')
    plt.figure(figsize=(12,6))
    plt.title(f'sales vs {col}')
    plt.xlabel('sales')
    plt.ylabel(col)

# %%
for col in df.columns[:-1]:
    plt.boxplot(data=df,x=col)
    plt.figure(figsize=(12,6))
    plt.title(col)

# %%
sns.pairplot(df,kind='reg')

# %%
sns.heatmap(df.corr(),annot=True)

# %%
import plotly.express as px

# %%
for i in df.columns[:-1]:
    fig=px.box(df,y=i,template="plotly_dark",
              color_discrete_sequence=px.colors.sequential.Aggrnyl)
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.hist(figsize=(12,6),bins=10,color='purple')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f890b885610>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=(12,6))
sns.violinplot(data=df)
